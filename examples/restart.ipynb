# %%
from uuid import UUID
from tests.controller.typed_graphdata import typed_eval
from tierkreis.consts import WORKERS_DIR
from tierkreis import run_graph
from tierkreis.storage import FileStorage
from tierkreis.executor import UvExecutor

storage = FileStorage(UUID(int=205), "restart_example", do_cleanup=True)
executor = UvExecutor(WORKERS_DIR, storage.logs_path)
run_graph(storage, executor, typed_eval(), {})
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 10
#       8 storage = FileStorage(UUID(int=205), "restart_example")
#       9 executor = UvExecutor(WORKERS_DIR, storage.logs_path)
# ---> 10 run_graph(storage, executor, typed_eval(), {})
#
# File ~/Documents/GitHub/tierkreis/tierkreis/tierkreis/controller/__init__.py:46, in run_graph(storage, executor, g, graph_inputs, n_iterations, polling_interval_seconds)
#      44 node_run_data = NodeRunData(Loc(), Eval((-1, "body"), inputs), [])
#      45 start(storage, executor, node_run_data)
# ---> 46 resume_graph(storage, executor, n_iterations, polling_interval_seconds)
#
# File ~/Documents/GitHub/tierkreis/tierkreis/tierkreis/controller/__init__.py:79, in resume_graph(storage, executor, n_iterations, polling_interval_seconds)
#      77 if storage.is_node_finished(Loc()):
#      78     break
# ---> 79 sleep(polling_interval_seconds)
#
# KeyboardInterrupt:

# %%
from tierkreis.controller.data.location import Loc

storage.restart_task(Loc().N(3).N(3))
# Out:
# {'-.N4', '-.N3.N5', '-.N3.N4'}
# ['-', '-.N3', '-.N3.N3']
